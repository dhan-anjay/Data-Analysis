# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing libraries to perform various operations
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#class to perform data preprocessing
class DataPreprocessor:

    def __init__(self, data):
        self.data = data

    #to find null values
    def find_null_values(self):
        missing = self.data.isnull().sum()
        missing = missing[missing > 0].sort_values(ascending = False)
        print(missing)

    #to remove duplicate values(rows)
    def remove_duplicates(self):
        self.data.drop_duplicates(inplace=True)

    #to get the mathematical description of dataset
    def describe_data(self):
        print(self.data.describe())

    #to handle missing values by mean
    def handle_missing_values_mean(self, columns):
        for column in columns:
          mode_imputer = SimpleImputer(missing_values = np.nan, strategy= 'mean')
          values = data[column].values.reshape(-1,1)
          mode_imputer.fit(values)
          self.data[column] = mode_imputer.transform(values)

    #handle missing values by most frequent
    def handle_missing_values_frequent(self, columns):
        for column in columns:
          mode_imputer = SimpleImputer(missing_values = np.nan, strategy= 'most_frequent')
          values = data[column].values.reshape(-1,1)
          mode_imputer.fit(values)
          self.data[column] = mode_imputer.transform(values)

    #to remove outliers
    def remove_outliers(self, columns, threshold=3):
        for col in columns:
            z_scores = (self.data[col] - self.data[col].mean()) / self.data[col].std()
            self.data = self.data[(z_scores.abs() < threshold)]

    #to get correlation
    def calculate_correlation(self):
        correlation_matrix = self.data.corr()
        print(correlation_matrix)

    #label encoding
    def label_encoding(self, column):
        label_encoder = LabelEncoder()
        self.data[column] = label_encoder.fit_transform(self.data[column])
        return self.data

    #data normalization
    def data_normalization(self, columns):
        scaler = MinMaxScaler()
        self.data[columns] = scaler.fit_transform(self.data[columns])

    #data standardization
    def data_standardization(self, columns):
        scaler = StandardScaler()
        self.data[columns] = scaler.fit_transform(self.data[columns])

    #applying PCA
    def apply_PCA(self, columns, n_components):
        pca = PCA(n_components=n_components)
        pca_result = pca.fit_transform(self.data[columns])
        transformed_df = pd.DataFrame(data=pca_result, columns=[f'PC_{i + 1}' for i in range(n_components)])
        return transformed_df

    def split_data(self, features, target, test_size=0.2, validation_size=0.25, random_state=42):
        x = self.data[features]
        y = self.data[target]
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=random_state)
        x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=validation_size, random_state=random_state)
        return x_train, x_val, x_test, y_train, y_val, y_test
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#classification of dataset
class Classification:

    #applying KNN algorithm
    def knn( X_train, y_train, X_test, y_test):
        knn = KNeighborsClassifier(n_neighbors=3)
        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_test)
        accuracy = knn.score(X_test, y_test)
        print(f"Accuracy of k-NN (k=3) on test set: {accuracy:.2f}")

    #applying decisin tree
    def decision_tree(X_train, y_train, X_test, y_test):
        clf = DecisionTreeClassifier(random_state=42)
        clf.fit(X_train, y_train)
        accuracy = clf.score(X_test, y_test)
        print(f"Accuracy of Decision Tree on test set: {accuracy:.2f}")

    #applying random forest
    def random_forest(X_train, y_train, X_test, y_test):
        rf = RandomForestClassifier(n_estimators=100, random_state=42)
        rf.fit(X_train, y_train)
        accuracy = rf.score(X_test, y_test)
        print(f"Accuracy of Random Forest on test set: {accuracy:.2f}")

    #applying naive bayes
    def naive_bayes(X_train, y_train, X_test, y_test):
        gnb = GaussianNB()
        gnb.fit(X_train, y_train)
        accuracy = gnb.score(X_test, y_test)
        print(f"Accuracy of Gaussian Naive Bayes on test set: {accuracy:.2f}")

    #applying support vector machine
    def svm(X_train, y_train, X_test, y_test):
        svm = SVC(kernel='linear', random_state=42)
        svm.fit(X_train, y_train)
        accuracy = svm.score(X_test, y_test)
        print(f"Accuracy of SVM on test set: {accuracy:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#class to perform clustering of dataset
class Clustering:

  #applying k-means
  def kmeans(data, n_clusters):
      kmeans = KMeans(n_clusters=n_clusters)
      kmeans.fit(data)
      cluster_labels = kmeans.labels_
      clustered_data = data.copy()
      clustered_data['Cluster'] = cluster_labels
      return clustered_data

  #aplying dbscan
  def dbscan(data, eps, min_samples):
      dbscan = DBSCAN(eps=eps, min_samples=min_samples)
      cluster_labels = dbscan.fit_predict(data)
      clustered_data = data.copy()
      clustered_data['Cluster'] = cluster_labels
      return clustered_data

  #applying agglomerative_clustering
  def agglomerative_clustering(data, n_clusters):
      agg_clustering = AgglomerativeClustering(n_clusters=n_clusters)
      cluster_labels = agg_clustering.fit_predict(data)
      clustered_data = data.copy()
      clustered_data['Cluster'] = cluster_labels
      return clustered_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#performing apriori algorithm
class Rule_Mining:

  def perform_apriori(data, min_support, min_threshold):
      frequent_itemsets = apriori(data, min_support=min_support, use_colnames=True)
      rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_threshold)
      return rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Reading the data
data = pd.read_csv("/content/drive/MyDrive/Wines.csv")
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Unnamed: 0  Fixed_Acidity  Volatile_Acidity  Citric Acid  Sugar  \
# 0              1            3.8             0.310         0.02   11.1
# 1              2            3.9             0.225         0.40    4.2
# 2              3            4.2             0.170         0.36    1.8
# 3              4            4.2             0.215         0.23    5.1
# 4              5            4.4             0.460         0.10    2.8
# ...          ...            ...               ...          ...    ...
# 6492        6493           15.5             0.645         0.49    4.2
# 6493        6494           15.5             0.645         0.49    4.2
# 6494        6495           15.6             0.685         0.76    3.7
# 6495        6496           15.6             0.645         0.49    4.2
# 6496        6497           15.9             0.360         0.65    7.5
#
#       Chlorides  Fixed_Sulfur_dioxide  Total_Sulfur_dioxide  Density    pH  \
# 0         0.036                  20.0                 114.0  0.99248  3.75
# 1         0.030                  29.0                 118.0  0.98900  3.57
# 2         0.029                  93.0                 161.0  0.98999  3.65
# 3         0.041                  64.0                 157.0  0.99688  3.42
# 4         0.024                  31.0                 111.0  0.98816  3.48
# ...         ...                   ...                   ...      ...   ...
# 6492      0.095                  10.0                  23.0  1.00315  2.92
# 6493      0.095                  10.0                  23.0  1.00315  2.92
# 6494      0.100                   6.0                  43.0  1.00320  2.95
# 6495      0.095                  10.0                  23.0  1.00315  2.92
# 6496      0.096                  22.0                  71.0  0.99760  2.98
#
#       ...  Color  Quality Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 0     ...  White        6         NaN          NaN          NaN          NaN
# 1     ...  White        8         NaN          NaN          NaN          NaN
# 2     ...  White        7         NaN          NaN          NaN          NaN
# 3     ...  White        3         NaN          NaN          NaN          NaN
# 4     ...  White        6         NaN          NaN          NaN          NaN
# ...   ...    ...      ...         ...          ...          ...          ...
# 6492  ...    Red        5         NaN          NaN          NaN          NaN
# 6493  ...    Red        5         NaN          NaN          NaN          NaN
# 6494  ...    Red        7         NaN          NaN          NaN          NaN
# 6495  ...    Red        5         NaN          NaN          NaN          NaN
# 6496  ...    Red        5         NaN          NaN          NaN          NaN
#
#       Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 6492          NaN          NaN          NaN          NaN
# 6493          NaN          NaN          NaN          NaN
# 6494          NaN          NaN          NaN          NaN
# 6495          NaN          NaN          NaN          NaN
# 6496          NaN          NaN          NaN          NaN
#
# [6497 rows x 22 columns]

# %%
# Removing unnamed columns
data = data.iloc[:,1:14]
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Fixed_Acidity  Volatile_Acidity  Citric Acid  Sugar  Chlorides  \
# 0               3.8             0.310         0.02   11.1      0.036
# 1               3.9             0.225         0.40    4.2      0.030
# 2               4.2             0.170         0.36    1.8      0.029
# 3               4.2             0.215         0.23    5.1      0.041
# 4               4.4             0.460         0.10    2.8      0.024
# ...             ...               ...          ...    ...        ...
# 6492           15.5             0.645         0.49    4.2      0.095
# 6493           15.5             0.645         0.49    4.2      0.095
# 6494           15.6             0.685         0.76    3.7      0.100
# 6495           15.6             0.645         0.49    4.2      0.095
# 6496           15.9             0.360         0.65    7.5      0.096
#
#       Fixed_Sulfur_dioxide  Total_Sulfur_dioxide  Density    pH  Sulphates  \
# 0                     20.0                 114.0  0.99248  3.75       0.44
# 1                     29.0                 118.0  0.98900  3.57       0.36
# 2                     93.0                 161.0  0.98999  3.65       0.89
# 3                     64.0                 157.0  0.99688  3.42       0.44
# 4                     31.0                 111.0  0.98816  3.48       0.34
# ...                    ...                   ...      ...   ...        ...
# 6492                  10.0                  23.0  1.00315  2.92       0.74
# 6493                  10.0                  23.0  1.00315  2.92       0.74
# 6494                   6.0                  43.0  1.00320  2.95       0.68
# 6495                  10.0                  23.0  1.00315  2.92       0.74
# 6496                  22.0                  71.0  0.99760  2.98       0.84
#
#       Alcohol  Color  Quality
# 0        12.4  White        6
# 1        12.8  White        8
# 2        12.0  White        7
# 3         8.0  White        3
# 4        13.1  White        6
# ...       ...    ...      ...
# 6492     11.1    Red        5
# 6493     11.1    Red        5
# 6494     11.2    Red        7
# 6495     11.1    Red        5
# 6496     14.9    Red        5
#
# [6497 rows x 13 columns]

# %%
# Loading the data in Preprocessor class
preprocessor = DataPreprocessor(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Check for Null values
preprocessor.find_null_values()
# Out:
# Chlorides           16
# Color               11
# Volatile_Acidity    10
# Sugar                9
# Alcohol              9
# Citric Acid          7
# dtype: int64
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Imputing the Null Values for numerical columns
preprocessor.handle_missing_values_mean(['Chlorides', 'Volatile_Acidity', 'Sugar', 'Alcohol', 'Citric Acid'])

# Imputing the Null values for categorical columns
preprocessor.handle_missing_values_frequent(['Color'])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Check for null values after imputing
preprocessor.find_null_values()
# Out:
# Series([], dtype: int64)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Remove Duplicate Rows
preprocessor.remove_duplicates()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Details of data
preprocessor.describe_data()
# Out:
#        Fixed_Acidity  Volatile_Acidity  Citric Acid        Sugar    Chlorides  \
# count    5321.000000       5321.000000   5321.00000  5321.000000  5321.000000
# mean        7.214800          0.343975      0.31806     5.053267     0.056618
# std         1.319836          0.167988      0.14672     4.498275     0.036830
# min         3.800000          0.080000      0.00000     0.600000     0.009000
# 25%         6.400000          0.230000      0.24000     1.800000     0.038000
# 50%         7.000000          0.300000      0.31000     2.700000     0.047000
# 75%         7.700000          0.410000      0.40000     7.500000     0.066000
# max        15.900000          1.580000      1.66000    65.800000     0.611000
#
#        Fixed_Sulfur_dioxide  Total_Sulfur_dioxide      Density           pH  \
# count           5321.000000           5321.000000  5321.000000  5321.000000
# mean              30.039090            114.109942     0.994534     3.224689
# std               17.804258             56.768927     0.002966     0.160375
# min                1.000000              6.000000     0.987110     2.720000
# 25%               16.000000             74.000000     0.992200     3.110000
# 50%               28.000000            116.000000     0.994640     3.210000
# 75%               41.000000            153.000000     0.996770     3.330000
# max              289.000000            440.000000     1.038980     4.010000
#
#          Sulphates      Alcohol      Quality
# count  5321.000000  5321.000000  5321.000000
# mean      0.533319    10.547457     5.796091
# std       0.149755     1.183136     0.880208
# min       0.220000     8.000000     3.000000
# 25%       0.430000     9.500000     5.000000
# 50%       0.510000    10.400000     6.000000
# 75%       0.600000    11.400000     6.000000
# max       2.000000    14.900000     9.000000
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Correlation Analysis
preprocessor.calculate_correlation()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-36-66d9ea48ca9c>:45: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = self.data.corr()
#                       Fixed_Acidity  Volatile_Acidity  Citric Acid     Sugar  \
# Fixed_Acidity              1.000000          0.216835     0.319500 -0.106100
# Volatile_Acidity           0.216835          1.000000    -0.384596 -0.162789
# Citric Acid                0.319500         -0.384596     1.000000  0.146652
# Sugar                     -0.106100         -0.162789     0.146652  1.000000
# Chlorides                  0.282624          0.368182     0.049799 -0.121940
# Fixed_Sulfur_dioxide      -0.281723         -0.348448     0.132752  0.398637
# Total_Sulfur_dioxide      -0.327424         -0.400936     0.198385  0.487126
# Density                    0.478437          0.310440     0.090311  0.520229
# pH                        -0.271346          0.245592    -0.343946 -0.232602
# Sulphates                  0.305115          0.226598     0.056773 -0.174438
# Alcohol                   -0.100216         -0.069864    -0.005436 -0.303413
# Quality                   -0.080746         -0.264850     0.097122 -0.056314
#
#                       Chlorides  Fixed_Sulfur_dioxide  Total_Sulfur_dioxide  \
# Fixed_Acidity          0.282624             -0.281723             -0.327424
# Volatile_Acidity       0.368182             -0.348448             -0.400936
# Citric Acid            0.049799              0.132752              0.198385
# Sugar                 -0.121940              0.398637              0.487126
# Chlorides              1.000000             -0.184849             -0.267301
# Fixed_Sulfur_dioxide  -0.184849              1.000000              0.720464
# Total_Sulfur_dioxide  -0.267301              0.720464              1.000000
# Density                0.369413              0.005927              0.006681
# pH                     0.026939             -0.141615             -0.222928
# Sulphates              0.403829             -0.198385             -0.275810
# Alcohol               -0.270606             -0.169951             -0.248118
# Quality               -0.202840              0.054310             -0.050226
#
#                        Density        pH  Sulphates   Alcohol   Quality
# Fixed_Acidity         0.478437 -0.271346   0.305115 -0.100216 -0.080746
# Volatile_Acidity      0.310440  0.245592   0.226598 -0.069864 -0.264850
# Citric Acid           0.090311 -0.343946   0.056773 -0.005436  0.097122
# Sugar                 0.520229 -0.232602  -0.174438 -0.303413 -0.056314
# Chlorides             0.369413  0.026939   0.403829 -0.270606 -0.202840
# Fixed_Sulfur_dioxide  0.005927 -0.141615  -0.198385 -0.169951  0.054310
# Total_Sulfur_dioxide  0.006681 -0.222928  -0.275810 -0.248118 -0.050226
# Density               1.000000  0.033986   0.283004 -0.667242 -0.326965
# pH                    0.033986  1.000000   0.167895  0.092816  0.040104
# Sulphates             0.283004  0.167895   1.000000 -0.019533  0.041213
# Alcohol              -0.667242  0.092816  -0.019533  1.000000  0.469335
# Quality              -0.326965  0.040104   0.041213  0.469335  1.000000

# %%
# Remove Outliers
column_names_array = data.columns.tolist()
column_names_array.remove('Color')
column_names_array.remove('Quality')

preprocessor.remove_outliers(column_names_array)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Perform Label Encoding in the Categorical column named Color
data = preprocessor.label_encoding('Color')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Storing the Target column seperately and removing it from the dataset for performing preprocessing
Quality_column = data.pop('Quality')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Performing Normalization and Standardization
preprocessor.data_normalization(column_names_array)
preprocessor.data_standardization(column_names_array)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Applying Principal Component Analysis(PCA)
new_data = preprocessor.apply_PCA(['Alcohol', 'Volatile_Acidity'], 2)
new_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           PC_1      PC_2
# 0    -1.829613  0.828870
# 1     0.988842 -2.084445
# 2    -0.894134  2.122585
# 3    -1.379031  1.279452
# 4     0.022657  1.964669
# ...        ...       ...
# 4862  0.192850  0.940743
# 4863  0.923273 -0.358836
# 4864 -0.486793  1.335807
# 4865 -0.292048  0.097609
# 4866  0.623067  0.415666
#
# [4867 rows x 2 columns]

# %%
# Adding back the Quality column in dataset
data['Quality'] = Quality_column
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Data Partioning
column_names_array = data.columns.tolist()
column_names_array.remove('Quality')
features = column_names_array

x_train, x_val, x_test, y_train, y_val, y_test = preprocessor.split_data(features=features, target='Quality')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Performing KNN Classification
Classification.knn(x_train, y_train, x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Accuracy of k-NN (k=3) on test set: 0.49

# %%
# Performing Decision Tree Classifier
Classification.decision_tree(x_train, y_train, x_test, y_test)
# Out:
# Accuracy of Decision Tree on test set: 0.47
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Performing Random Forest Classifier
Classification.random_forest(x_train, y_train, x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Accuracy of Random Forest on test set: 0.57

# %%
# Performing Naive Bayes Classifier
Classification.naive_bayes(x_train, y_train, x_test, y_test)
# Out:
# Accuracy of Gaussian Naive Bayes on test set: 0.44
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Performing Support Vector Machines(SVM) Classifier
Classification.svm(x_train, y_train, x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Accuracy of SVM on test set: 0.53

# %%
# Performing K Means clustering
clustered_data = Clustering.kmeans(data,3)
clustered_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#       Fixed_Acidity  Volatile_Acidity  Citric Acid     Sugar  Chlorides  \
# 1         -2.977395         -0.707632     0.660336 -0.196167  -1.015666
# 3         -2.697191         -0.774708    -0.606986  0.014047  -0.501280
# 4         -2.510388          0.868647    -1.576115 -0.523167  -1.296240
# 5         -2.510388         -0.070413     0.585788 -0.172810  -1.015666
# 6         -2.510388          1.405252    -1.650664  0.014047  -0.641567
# ...             ...               ...          ...       ...        ...
# 6362       3.747500          0.801571     3.120433 -0.429739   0.667778
# 6364       3.747500          0.399117     1.704013 -0.546525   2.023885
# 6365       3.747500          0.600344     1.182175 -0.558203   1.556262
# 6366       3.747500         -0.137489     1.629465 -0.663310   0.387204
# 6368       3.747500          0.734495     0.809433 -0.663310   0.574253
#
#       Fixed_Sulfur_dioxide  Total_Sulfur_dioxide   Density        pH  \
# 1                -0.069739              0.036637 -1.899166  2.256270
# 3                 2.071708              0.753707  0.926394  1.273905
# 4                 0.052629             -0.092068 -2.200367  1.666851
# 5                 0.052629              0.202115 -1.884823  1.535869
# 6                 1.337497             -0.349478 -1.461706  1.208414
# ...                    ...                   ...       ...       ...
# 6362             -1.476975             -1.728460  1.543141 -0.363369
# 6364             -0.559212             -0.275932  2.081002 -0.625333
# 6365             -1.293423             -1.507823  1.098510  0.095068
# 6366             -1.660528             -1.949097  0.510449 -1.345734
# 6368             -0.987502             -1.783619  1.177396  0.160559
#
#       Sulphates   Alcohol  Color  Quality  Cluster
# 1     -1.274492  1.879832      1        8        0
# 3     -0.635375 -2.173142      1        3        2
# 4     -1.434271  2.133142      1        6        0
# 5     -1.274492  1.879832      1        8        0
# 6     -0.954933  1.373210      1        7        0
# ...         ...       ...    ...      ...      ...
# 6362   1.122197  0.528840      0        6        1
# 6364  -0.076147 -0.906588      0        5        1
# 6365   2.000983  1.288773      0        7        1
# 6366   2.480321  0.275529      0        7        1
# 6368   0.403191 -0.146655      0        6        1
#
# [4867 rows x 14 columns]

# %%
# Performing DBSCAN
eps = 0.5
min_samples = 5
clustered_data = Clustering.dbscan(data, eps, min_samples)
clustered_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Fixed_Acidity  Volatile_Acidity  Citric Acid     Sugar  Chlorides  \
# 1         -2.977395         -0.707632     0.660336 -0.196167  -1.015666
# 3         -2.697191         -0.774708    -0.606986  0.014047  -0.501280
# 4         -2.510388          0.868647    -1.576115 -0.523167  -1.296240
# 5         -2.510388         -0.070413     0.585788 -0.172810  -1.015666
# 6         -2.510388          1.405252    -1.650664  0.014047  -0.641567
# ...             ...               ...          ...       ...        ...
# 6362       3.747500          0.801571     3.120433 -0.429739   0.667778
# 6364       3.747500          0.399117     1.704013 -0.546525   2.023885
# 6365       3.747500          0.600344     1.182175 -0.558203   1.556262
# 6366       3.747500         -0.137489     1.629465 -0.663310   0.387204
# 6368       3.747500          0.734495     0.809433 -0.663310   0.574253
#
#       Fixed_Sulfur_dioxide  Total_Sulfur_dioxide   Density        pH  \
# 1                -0.069739              0.036637 -1.899166  2.256270
# 3                 2.071708              0.753707  0.926394  1.273905
# 4                 0.052629             -0.092068 -2.200367  1.666851
# 5                 0.052629              0.202115 -1.884823  1.535869
# 6                 1.337497             -0.349478 -1.461706  1.208414
# ...                    ...                   ...       ...       ...
# 6362             -1.476975             -1.728460  1.543141 -0.363369
# 6364             -0.559212             -0.275932  2.081002 -0.625333
# 6365             -1.293423             -1.507823  1.098510  0.095068
# 6366             -1.660528             -1.949097  0.510449 -1.345734
# 6368             -0.987502             -1.783619  1.177396  0.160559
#
#       Sulphates   Alcohol  Color  Quality  Cluster
# 1     -1.274492  1.879832      1        8       -1
# 3     -0.635375 -2.173142      1        3       -1
# 4     -1.434271  2.133142      1        6       -1
# 5     -1.274492  1.879832      1        8       -1
# 6     -0.954933  1.373210      1        7       -1
# ...         ...       ...    ...      ...      ...
# 6362   1.122197  0.528840      0        6       -1
# 6364  -0.076147 -0.906588      0        5       -1
# 6365   2.000983  1.288773      0        7       -1
# 6366   2.480321  0.275529      0        7       -1
# 6368   0.403191 -0.146655      0        6       -1
#
# [4867 rows x 14 columns]

# %%
# Performing agglomerative clustering
n_clusters = 3
Clustering.agglomerative_clustering(data, n_clusters)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Fixed_Acidity  Volatile_Acidity  Citric Acid     Sugar  Chlorides  \
# 1         -2.977395         -0.707632     0.660336 -0.196167  -1.015666
# 3         -2.697191         -0.774708    -0.606986  0.014047  -0.501280
# 4         -2.510388          0.868647    -1.576115 -0.523167  -1.296240
# 5         -2.510388         -0.070413     0.585788 -0.172810  -1.015666
# 6         -2.510388          1.405252    -1.650664  0.014047  -0.641567
# ...             ...               ...          ...       ...        ...
# 6362       3.747500          0.801571     3.120433 -0.429739   0.667778
# 6364       3.747500          0.399117     1.704013 -0.546525   2.023885
# 6365       3.747500          0.600344     1.182175 -0.558203   1.556262
# 6366       3.747500         -0.137489     1.629465 -0.663310   0.387204
# 6368       3.747500          0.734495     0.809433 -0.663310   0.574253
#
#       Fixed_Sulfur_dioxide  Total_Sulfur_dioxide   Density        pH  \
# 1                -0.069739              0.036637 -1.899166  2.256270
# 3                 2.071708              0.753707  0.926394  1.273905
# 4                 0.052629             -0.092068 -2.200367  1.666851
# 5                 0.052629              0.202115 -1.884823  1.535869
# 6                 1.337497             -0.349478 -1.461706  1.208414
# ...                    ...                   ...       ...       ...
# 6362             -1.476975             -1.728460  1.543141 -0.363369
# 6364             -0.559212             -0.275932  2.081002 -0.625333
# 6365             -1.293423             -1.507823  1.098510  0.095068
# 6366             -1.660528             -1.949097  0.510449 -1.345734
# 6368             -0.987502             -1.783619  1.177396  0.160559
#
#       Sulphates   Alcohol  Color  Quality  Cluster
# 1     -1.274492  1.879832      1        8        0
# 3     -0.635375 -2.173142      1        3        2
# 4     -1.434271  2.133142      1        6        0
# 5     -1.274492  1.879832      1        8        0
# 6     -0.954933  1.373210      1        7        0
# ...         ...       ...    ...      ...      ...
# 6362   1.122197  0.528840      0        6        1
# 6364  -0.076147 -0.906588      0        5        1
# 6365   2.000983  1.288773      0        7        1
# 6366   2.480321  0.275529      0        7        1
# 6368   0.403191 -0.146655      0        6        1
#
# [4867 rows x 14 columns]

# %%
# Performing apriori algorithm (Association Rule Mining)

data_encoded = pd.get_dummies(data)
# Binarize the dataset based on some threshold or specific conditions
data_binarized = data_encoded.applymap(lambda x: 1 if x >= 1 else 0)

min_supp = 0.1
min_thresh = 0.7
association_rules = Rule_Mining.perform_apriori(data_binarized, min_support=min_supp, min_threshold=min_thresh)
association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                         antecedents       consequents  antecedent support  \
# 0                   (Fixed_Acidity)         (Quality)            0.143209
# 1                (Volatile_Acidity)         (Quality)            0.163961
# 2                     (Citric Acid)           (Color)            0.147524
# 3                     (Citric Acid)         (Quality)            0.147524
# 4                           (Sugar)           (Color)            0.175057
# 5                           (Sugar)         (Quality)            0.175057
# 6                       (Chlorides)         (Quality)            0.166221
# 7            (Fixed_Sulfur_dioxide)           (Color)            0.176906
# 8            (Fixed_Sulfur_dioxide)         (Quality)            0.176906
# 9            (Total_Sulfur_dioxide)           (Color)            0.165811
# 10           (Total_Sulfur_dioxide)         (Quality)            0.165811
# 11                        (Density)         (Quality)            0.184508
# 12                             (pH)         (Quality)            0.167249
# 13                      (Sulphates)         (Quality)            0.150606
# 14                        (Alcohol)           (Color)            0.190466
# 15                        (Alcohol)         (Quality)            0.190466
# 16                        (Quality)           (Color)            1.000000
# 17                          (Color)         (Quality)            0.778303
# 18           (Quality, Citric Acid)           (Color)            0.147524
# 19             (Color, Citric Acid)         (Quality)            0.113417
# 20                    (Citric Acid)  (Quality, Color)            0.147524
# 21                 (Quality, Sugar)           (Color)            0.175057
# 22                   (Color, Sugar)         (Quality)            0.174029
# 23                          (Sugar)  (Quality, Color)            0.175057
# 24  (Quality, Fixed_Sulfur_dioxide)           (Color)            0.176906
# 25    (Color, Fixed_Sulfur_dioxide)         (Quality)            0.174646
# 26           (Fixed_Sulfur_dioxide)  (Quality, Color)            0.176906
# 27  (Quality, Total_Sulfur_dioxide)           (Color)            0.165811
# 28    (Color, Total_Sulfur_dioxide)         (Quality)            0.165605
# 29           (Total_Sulfur_dioxide)  (Quality, Color)            0.165811
# 30                 (Color, Density)         (Quality)            0.105815
# 31               (Quality, Alcohol)           (Color)            0.190466
# 32                 (Color, Alcohol)         (Quality)            0.159441
# 33                        (Alcohol)  (Quality, Color)            0.190466
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             1.000000  0.143209    1.000000  1.000000  0.000000         inf
# 1             1.000000  0.163961    1.000000  1.000000  0.000000         inf
# 2             0.778303  0.113417    0.768802  0.987793 -0.001402    0.958907
# 3             1.000000  0.147524    1.000000  1.000000  0.000000         inf
# 4             0.778303  0.174029    0.994131  1.277307  0.037782   37.777193
# 5             1.000000  0.175057    1.000000  1.000000  0.000000         inf
# 6             1.000000  0.166221    1.000000  1.000000  0.000000         inf
# 7             0.778303  0.174646    0.987224  1.268432  0.036959   17.352840
# 8             1.000000  0.176906    1.000000  1.000000  0.000000         inf
# 9             0.778303  0.165605    0.998761  1.283255  0.036554  178.909595
# 10            1.000000  0.165811    1.000000  1.000000  0.000000         inf
# 11            1.000000  0.184508    1.000000  1.000000  0.000000         inf
# 12            1.000000  0.167249    1.000000  1.000000  0.000000         inf
# 13            1.000000  0.150606    1.000000  1.000000  0.000000         inf
# 14            0.778303  0.159441    0.837109  1.075557  0.011201    1.361015
# 15            1.000000  0.190466    1.000000  1.000000  0.000000         inf
# 16            0.778303  0.778303    0.778303  1.000000  0.000000    1.000000
# 17            1.000000  0.778303    1.000000  1.000000  0.000000         inf
# 18            0.778303  0.113417    0.768802  0.987793 -0.001402    0.958907
# 19            1.000000  0.113417    1.000000  1.000000  0.000000         inf
# 20            0.778303  0.113417    0.768802  0.987793 -0.001402    0.958907
# 21            0.778303  0.174029    0.994131  1.277307  0.037782   37.777193
# 22            1.000000  0.174029    1.000000  1.000000  0.000000         inf
# 23            0.778303  0.174029    0.994131  1.277307  0.037782   37.777193
# 24            0.778303  0.174646    0.987224  1.268432  0.036959   17.352840
# 25            1.000000  0.174646    1.000000  1.000000  0.000000         inf
# 26            0.778303  0.174646    0.987224  1.268432  0.036959   17.352840
# 27            0.778303  0.165605    0.998761  1.283255  0.036554  178.909595
# 28            1.000000  0.165605    1.000000  1.000000  0.000000         inf
# 29            0.778303  0.165605    0.998761  1.283255  0.036554  178.909595
# 30            1.000000  0.105815    1.000000  1.000000  0.000000         inf
# 31            0.778303  0.159441    0.837109  1.075557  0.011201    1.361015
# 32            1.000000  0.159441    1.000000  1.000000  0.000000         inf
# 33            0.778303  0.159441    0.837109  1.075557  0.011201    1.361015
#
#     zhangs_metric
# 0        0.000000
# 1        0.000000
# 2       -0.014289
# 3        0.000000
# 4        0.263173
# 5        0.000000
# 6        0.000000
# 7        0.257109
# 8        0.000000
# 9        0.264606
# 10       0.000000
# 11       0.000000
# 12       0.000000
# 13       0.000000
# 14       0.086777
# 15       0.000000
# 16       0.000000
# 17       0.000000
# 18      -0.014289
# 19       0.000000
# 20      -0.014289
# 21       0.263173
# 22       0.000000
# 23       0.263173
# 24       0.257109
# 25       0.000000
# 26       0.257109
# 27       0.264606
# 28       0.000000
# 29       0.264606
# 30       0.000000
# 31       0.086777
# 32       0.000000
# 33       0.086777
